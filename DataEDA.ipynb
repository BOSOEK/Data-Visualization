# %%
cd ../datasets_rw/challenge-dataset/train/labels
# Out:
# /home/dnadrone36/datasets_rw/challenge-dataset/train/labels

# %%
import os 
file_list = os.listdir('./') 
print (len(file_list))
# Out:
# 1466

# %% [markdown]
# train label 파일은 총 1466개임
# #### 즉 dataset_rw의 train 데이터의 개수는 1466개이다.

# %%
for i in range(1466) :
    if file_list[i] == '.ipynb_checkpoints':
        continue
    f = open(file_list[i], 'r')
    print(f.readline(), end='')
# Out:
# 0 0.744792 0.703704 0.019792 0.051852
# 0 0.707552 0.483796 0.019792 0.049537
# 0 0.469792 0.842593 0.034375 0.081944
# 0 0.183073 0.624537 0.033073 0.081944
# 0 0.675260 0.314815 0.016667 0.037037
# 0 0.489063 0.123611 0.033333 0.078241
# 0 0.735417 0.629167 0.020052 0.051389
# 0 0.194010 0.182407 0.022656 0.077778
# 0 0.812500 0.688426 0.033073 0.082407
# 0 0.471875 0.536111 0.034115 0.081481
# 0 0.739583 0.654167 0.020313 0.050926
# 0 0.662240 0.226852 0.019792 0.050000
# 0 0.182292 0.592130 0.031510 0.081019
# 0 0.776042 0.892130 0.019271 0.050926
# 0 0.496615 0.095833 0.033854 0.078241
# 0 0.823958 0.335185 0.033333 0.075463
# 0 0.479948 0.332407 0.033854 0.071759
# 0 0.824479 0.343981 0.033854 0.081481
# 0 0.484635 0.130093 0.033854 0.078704
# 0 0.469010 0.871759 0.033854 0.082870
# 0 0.469531 0.676852 0.034115 0.081481
# 0 0.744792 0.661111 0.019531 0.051389
# 0 0.621615 0.018981 0.015365 0.038426
# 0 0.621094 0.019444 0.017188 0.038889
# 0 0.781250 0.922222 0.019792 0.050926
# ...

# %% [markdown]
# #### label은 object box의 4개 좌표를 표시하고 있는 것 같다.
